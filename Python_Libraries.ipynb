# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaMGMG/Python-Libraries/blob/main/Python_Libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Pandas series and dataframe

# %%
#Pandas series has 1 column and 1 data type.
#Pandas dataframe has multiple columns and multiple data type.

#Dataframe has 3 parts/entities
# Indexing
# Columns
# Rows

# %%
import pandas as pd

# %% [markdown]
# Pandas series

# %%
pd_series = pd.Series([10,20,30,40,50])

# %%
pd_series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd_series.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
pd_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#create pandas series using dictionary.
my_dict = { 'A' : 1, 'B': 2, 'C': 3}
dict_series = pd.Series(my_dict)
dict_series
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %% [markdown]
# Pandas dataframe

# %%
temp_df = pd.DataFrame(data=[[1,2,3],['X','Y','Z']])
print(temp_df)
# Out:
#    0  1  2
# 0  1  2  3
# 1  X  Y  Z

# %%
my_df = temp_df.transpose()

# %%
my_df.columns = ['Nums','Alpas']
my_df
# Out:
#   Nums Alpas
# 0    1     X
# 1    2     Y
# 2    3     Z

# %%
# Create a dataframe using a pandas library
names_df = pd.DataFrame(data=['Deepa', 'DEEPA','deepa'], columns=['names'])
names_df
# Out:
#    names
# 0  Deepa
# 1  DEEPA
# 2  deepa

# %%
# Create a dataframe using a pandas library
couples_df = pd.DataFrame(data=[['Praveen', 'PRAVEEN','praveen'],['Deepa', 'DEEPA','deepa']], columns=['Camecase', 'Capital', 'Small'])
couples_df
# Out:
#   Camecase  Capital    Small
# 0  Praveen  PRAVEEN  praveen
# 1    Deepa    DEEPA    deepa

# %%
couples_transposed_df=couples_df.transpose()
couples_transposed_df
# Out:
#                 0      1
# Camecase  Praveen  Deepa
# Capital   PRAVEEN  DEEPA
# Small     praveen  deepa

# %%
couples_df.columns
# Out:
# Index(['Camecase', 'Capital', 'Small'], dtype='object')

# %%
couples_transposed_df.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
couples_df.index = ['Male', 'Female']
couples_df
# Out:
#        Camecase  Capital    Small
# Male    Praveen  PRAVEEN  praveen
# Female    Deepa    DEEPA    deepa

# %% [markdown]
# #connecting google drive with colab

# %%
from google.colab import drive

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Growth School/python/datasets/customers.csv')

# %%
df.shape
# Out:
# (100, 12)

# %%
df.head()
#df.head() will print first 5 records by default. Optionally can also specify the number of rows you want to visualize
df.head(10)
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# ...

# %% [markdown]
# ## Pandas - Filtering, Grouping

# %%
#Sort the data based on Subscription Date.
df.sort_values('Subscription Date')
# Out:
#     Index      Customer Id First Name   Last Name                     Company  \
# 8       9  C2dE4dEEc489ae0     Sheryl      Meyers              Browning-Simon
# 66     67  2A13F74EAa7DA6c    Makayla      Cannon               Henderson Inc
# 69     70  CC68FD1D3Bbbf22      Riley        Good                    Wade PLC
# 73     74  A3F76Be153Df4a3      Anita      Benson                 Parrish Ltd
# 84     85  03A1E62ADdeb31c      Corey        Holt  Mcdonald, Bird and Ramirez
# ..    ...              ...        ...         ...                         ...
# 85     86  C6763c99d0bd16D       Emma  Cunningham                Stephens Inc
# 43     44  D3fC11A9C235Dc6       Luis       Greer                   Cross PLC
# 63     64  FCBdfCEAe20A8Dc      Chloe  Hutchinson                   Simon LLC
# 25     26  09D7D7C8Fe09aea     Marcus       Moody                   Giles Ltd
# 27     28  b92EBfdF8a3f0E6  Frederick      Harper   Hinton, Chaney and Stokes
#
# ...

# %%
# Filter the entries which have Subscription Date before 2020-02-18
df[df['Subscription Date'] < '2020-02-18']
# Out:
#     Index      Customer Id First Name Last Name         Company          City  \
# 8       9  C2dE4dEEc489ae0     Sheryl    Meyers  Browning-Simon  Robersonstad
# 66     67  2A13F74EAa7DA6c    Makayla    Cannon   Henderson Inc    Georgeport
# 69     70  CC68FD1D3Bbbf22      Riley      Good        Wade PLC    Erikaville
# 73     74  A3F76Be153Df4a3      Anita    Benson     Parrish Ltd   Skinnerport
#
#                Country                 Phone 1              Phone 2  \
# 8               Cyprus       854-138-4911x5772  +1-448-910-2276x729
# 66       New Caledonia  001-215-801-6392x46009         027-609-6460
# 69              Canada              6977745822         855-436-7641
# 73  Russian Federation      874.617.5668x69878   (399)820-6418x0071
#
#                       Email Subscription Date                    Website
# 8   mariokhan@ryan-pope.org        2020-01-13   https://www.bullock.net/
# 66   scottcurtis@hurley.biz        2020-01-20  http://www.velazquez.net/
# ...

# %%
df[(df['Country']=='Chile') & (df['First Name']=='Sheryl')]
# Out:
#    Index      Customer Id First Name Last Name          Company          City  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group  East Leonard
#
#   Country       Phone 1           Phone 2                     Email  \
# 0   Chile  229.077.5154  397.884.0519x718  zunigavanessa@smith.info
#
#   Subscription Date                     Website
# 0        2020-08-24  http://www.stephenson.com/

# %%
#df.groupby('Country').count() #This code will give the count by each column. So choose the groupby column as in the next line.
# df.groupby('Country')['Index'].count()

#Some more experiments
# 1. Apply the group by on filtered results
# df.groupby('Subscription Date')['Index'].count()
df[df['Subscription Date'] >= '2022-04-12'].groupby('Subscription Date')['Index'].count()
# Out:
# Subscription Date
# 2022-04-12    1
# 2022-05-13    1
# 2022-05-15    2
# 2022-05-24    1
# 2022-05-26    1
# Name: Index, dtype: int64

# %% [markdown]
# Pandas Aggregation

# %%
# Find the total number of each gender and there total income.
# Then, pass the multiple conditions as a  dictionary.
df.groupby('Name').agg({'CustomerID':'count', 'Salary':'sum'})
# Aliasing the name of output
df.groupby('Name').agg({'CustomerID':'count', 'Salary':'sum'}).rename(columns={'CustomerID':'Number of Customers'})
# OR
df.groupby('Name').agg(TotalCustomers = ('CustomerID','count'), TotalSalary = ('Salary','sum'))
